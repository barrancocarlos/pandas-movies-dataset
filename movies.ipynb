# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

# %%
data = pd.read_csv("movies.csv", index_col="Film")

# %%
main_table = pd.DataFrame(data)

# %%
main_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, Zack and Miri Make a Porno to (500) Days of Summer
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Genre              77 non-null     object
#  1   Lead Studio        77 non-null     object
#  2   Audience score %   77 non-null     int64
#  3   Profitability      77 non-null     float64
#  4   Rotten Tomatoes %  77 non-null     int64
#  5   Worldwide Gross    77 non-null     object
#  6   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.6+ KB

# %%
main_table.head(20)
# Out:
#                                          Genre            Lead Studio  \
# Film
# Zack and Miri Make a Porno             Romance  The Weinstein Company
# Youth in Revolt                         Comedy  The Weinstein Company
# You Will Meet a Tall Dark Stranger      Comedy            Independent
# When in Rome                            Comedy                 Disney
# What Happens in Vegas                   Comedy                    Fox
# Water For Elephants                      Drama       20th Century Fox
# WALL-E                               Animation                 Disney
# Waitress                               Romance            Independent
# Waiting For Forever                    Romance            Independent
# Valentine's Day                         Comedy           Warner Bros.
# Tyler Perry's Why Did I get Married    Romance            Independent
# Twilight: Breaking Dawn                Romance            Independent
# ...

# %%
main_table.isnull().sum()
# Out:
# Genre                0
# Lead Studio          0
# Audience score %     0
# Profitability        0
# Rotten Tomatoes %    0
# Worldwide Gross      0
# Year                 0
# dtype: int64

# %%
main_table.describe()
# Out:
#        Audience score %  Profitability  Rotten Tomatoes %         Year
# count         77.000000      77.000000          77.000000    77.000000
# mean          63.727273       4.599483          46.701299  2009.077922
# std           13.657113       8.031990          26.095001     1.354974
# min           35.000000       0.000000           3.000000  2007.000000
# 25%           52.000000       1.751351          26.000000  2008.000000
# 50%           64.000000       2.642353          45.000000  2009.000000
# 75%           76.000000       5.103117          64.000000  2010.000000
# max           89.000000      66.934000          96.000000  2011.000000

# %%
main_table['Genre'].value_counts().head(10)
# Out:
# Comedy       41
# Romance      13
# Drama        13
# Animation     4
# comedy        1
# Romence       1
# Action        1
# Fantasy       1
# Comdy         1
# romance       1
# Name: Genre, dtype: int64

# %%
genre_col = main_table[['Genre']]
type(genre_col)
# Out:
# pandas.core.frame.DataFrame

# %%
subset_genre = main_table[['Genre']]
subset_genre.head(10)
# Out:
#                                         Genre
# Film
# Zack and Miri Make a Porno            Romance
# Youth in Revolt                        Comedy
# You Will Meet a Tall Dark Stranger     Comedy
# When in Rome                           Comedy
# What Happens in Vegas                  Comedy
# Water For Elephants                     Drama
# WALL-E                              Animation
# Waitress                              Romance
# Waiting For Forever                   Romance
# Valentine's Day                        Comedy

# %%
details = main_table.loc["Midnight in Paris"]

details
# Out:
# Genre                 Romence
# Lead Studio              Sony
# Audience score %           84
# Profitability         8.74471
# Rotten Tomatoes %          93
# Worldwide Gross      $148.66
# Year                     2011
# Name: Midnight in Paris, dtype: object

# %%
main_table[(main_table['Lead Studio'] == 'Disney')].head(10)
# Out:
#                                         Genre Lead Studio  Audience score %  \
# Film
# When in Rome                           Comedy      Disney                44
# WALL-E                              Animation      Disney                89
# The Proposal                           Comedy      Disney                74
# Tangled                             Animation      Disney                88
# High School Musical 3: Senior Year     Comedy      Disney                76
# Gnomeo and Juliet                   Animation      Disney                52
# Gnomeo and Juliet                   Animation      Disney                52
# Enchanted                              Comedy      Disney                80
#
#                                     Profitability  Rotten Tomatoes %  \
# Film
# When in Rome                             0.000000                 15
# WALL-E                                   2.896019                 96
# ...

# %%
main_table[main_table['Rotten Tomatoes %'] >= 90].head(10)
# Out:
#                        Genre Lead Studio  Audience score %  Profitability  \
# Film
# WALL-E             Animation      Disney                89       2.896019
# Midnight in Paris    Romence        Sony                84       8.744706
# Knocked Up            Comedy   Universal                83       6.636402
# Enchanted             Comedy      Disney                80       4.005737
#
#                    Rotten Tomatoes % Worldwide Gross  Year
# Film
# WALL-E                            96        $521.28   2008
# Midnight in Paris                 93        $148.66   2011
# Knocked Up                        91           $219   2007
# Enchanted                         93        $340.49   2007

# %%
main_table[
    ((main_table['Year'] >= 2007) & (main_table['Year'] <= 2009))
    & (main_table['Rotten Tomatoes %'] > 80)    
]
# Out:
#                             Genre  Lead Studio  Audience score %  \
# Film
# WALL-E                  Animation       Disney                89
# Waitress                  Romance  Independent                67
# Rachel Getting Married      Drama  Independent                61
# Knocked Up                 Comedy    Universal                83
# Enchanted                  Comedy       Disney                80
# A Serious Man               Drama    Universal                64
# (500) Days of Summer       comedy          Fox                81
#
#                         Profitability  Rotten Tomatoes % Worldwide Gross  Year
# Film
# WALL-E                       2.896019                 96        $521.28   2008
# Waitress                    11.089741                 89         $22.18   2007
# Rachel Getting Married       1.384167                 85         $16.61   2008
# Knocked Up                   6.636402                 91           $219   2007
# ...

# %%
main_table['Rotten Tomatoes %'] = main_table['Rotten Tomatoes %'].astype(float)

# %%
main_table['Worldwide Gross'] = main_table['Worldwide Gross'].replace({'\$':''}, regex = True)
main_table['Worldwide Gross'] = main_table['Worldwide Gross'].astype(float)

# %%
main_table.plot(kind='scatter', x='Rotten Tomatoes %', y='Worldwide Gross', title='Revenue vs Rating');

# %%
main_table['Rotten Tomatoes %'].plot(kind='hist', title='Rating');

# %%
main_table['Rotten Tomatoes %'].plot(kind="box");
